# %%
from functions.sky_functions import *
from functions.alignment_functions import *
from functions.visualization_functions import *

from astropy.table import Table

# %% [markdown]
# ## Load in data
# Must be a catalog of 2d shapes with compex ellipticities [E1, E2] and positions [RA, DEC]
# If using weights, r-w1 color also necessary

# %%
LRGs = Table.read('sample_data/sample_LRGs.fits')

# %%
LRGs[:4]
# Out:
# <Table length=4>
#         RA                DEC           FLUX_R  ...     rz       rw1
#      float64            float64        float32  ...  float32   float32
# ------------------ ------------------ --------- ... --------- ---------
# 200.01126510964488  1.184772721711952  6.751958 ... 1.2541158 2.2931266
#  200.0145060556931  1.178786174342609   8.18776 ... 1.2520272 2.1452644
#  200.0170503174841 1.2067389904454537  8.926818 ... 1.1869754 2.0725982
# 200.01745600192672 1.1619329580951878 3.6599488 ... 1.4809972   2.67596

# %% [markdown]
# ## Measure alignment

# %%
measure_alignment(LRGs, weights='sample_data/rw1_weights.npy', save_path='sample_results/alignment0_', delta_rz_max=2)
# Out:
# /global/common/software/desi/cori/desiconda/20200801-1.4.0-spec/conda/lib/python3.8/site-packages/astropy/table/table.py:3075: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   result = self.as_array() == other
# WARNING: AstropyDeprecationWarning: The `representation` keyword/property name is deprecated in favor of `representation_type` [astropy.coordinates.baseframe]
# Working on 1/100
# So far it's been 0.004  minutes
#
# Working on 11/100
# So far it's been 0.032  minutes
#
# Working on 21/100
# So far it's been 0.062  minutes
#
# Working on 31/100
# So far it's been 0.093  minutes
#
# Working on 41/100
# So far it's been 0.127  minutes
#
# Working on 51/100
# So far it's been 0.159  minutes
#
# Working on 61/100
# So far it's been 0.189  minutes
#
# Working on 71/100
# So far it's been 0.222  minutes
#
# Working on 81/100
# So far it's been 0.257  minutes
#
# ...

# %% [markdown]
# #### Measuring alignment again, but without a stricter limit on delta_rz_max
# This is the maximum ammount of color difference that two galaxies can have to be counted as a pair. Generally, the closer two galaxies are in color space, the more likely they are to be physically associated.

# %%
measure_alignment(LRGs, weights='sample_data/rw1_weights.npy', save_path='sample_results/alignment1_', delta_rz_max=.1)
# Out:
# Working on 1/100
# So far it's been 0.002  minutes
#
# Working on 11/100
# So far it's been 0.016  minutes
#
# Working on 21/100
# So far it's been 0.03  minutes
#
# Working on 31/100
# So far it's been 0.044  minutes
#
# Working on 41/100
# So far it's been 0.057  minutes
#
# Working on 51/100
# So far it's been 0.07  minutes
#
# Working on 61/100
# So far it's been 0.084  minutes
#
# Working on 71/100
# So far it's been 0.098  minutes
#
# Working on 81/100
# So far it's been 0.111  minutes
#
# Working on 91/100
# So far it's been 0.125  minutes
#
# Finished! Total time:  0.1370182117  minutes

# %% [markdown]
# ## Plotting Results

# %%
plot_rel_e(results_paths=['sample_results/alignment0_', 'sample_results/alignment1_'], 
           labels=['|r-w1| < 2.0', '|r-w1| < 0.1'])

# %% [markdown]
# As you can see, galaxies which are more likely to be physically near each other are are more aligned.
